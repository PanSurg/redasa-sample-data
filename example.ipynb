# %%
from main import load_curations, get_annotation_spans

# %%
curations_df = load_curations()
curations_df
# Out:
#     dataObject  workerId quality  relevant checklist              studyType  \
# 0           17        19     Low      True      None                   None
# 1            7        13     Low     False      None                   None
# 2           11         4  Medium     False    strobe           Cohort Study
# 3            3        11  Medium      True      None                   None
# 4            6        13     Low     False      None                   None
# 5            2        11     Low     False    strobe           Cohort Study
# 6           13        16     Low     False      None                   None
# 7            4        14     Low     False      None                   None
# 8            8         5     Low      True      None                   None
# 9           13         8     Low     False      None                   None
# 10           9        16     Low     False      None                   None
# ...

# %%
get_annotation_spans(curations_df)
# Out:
#     dataObject  workerId  startOffset  endOffset      label
# 0           17        19         3533       3640  relevance
# 0           17        19         3641       3673    quality
# 0           17        19         3674       3829    summary
# 0           17        19         5874       6142    quality
# 0           17        19         6146       6326    summary
# ..         ...       ...          ...        ...        ...
# 39           5         3         8626       8697    quality
# 39           5         3         8994       9312  relevance
# 39           5         3         9746      10083  relevance
# 39           5         3        10215      10607    summary
# 39           5         3        10716      10905    summary
#
# [229 rows x 5 columns]
